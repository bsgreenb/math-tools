# %% [markdown]
# # Sources
# - Started with Khan [Precalc on Series](https://www.khanacademy.org/math/precalculus/x9e81a4f98389efdf:series)
# - Then did [AP Calc - Series on Khan](https://www.khanacademy.org/math/ap-calculus-bc/bc-series-new)
# - To really get these notes well-organized and proper, went through Paul's Math Notes.  Didn't end up much using Khan for notes, similar to my Integral notes went with PAul.
#
# # Sequences
#
# There are a variety of ways of denoting a sequence. Each of the following are equivalent ways of denoting a sequence.
#
# $$
# \left\{a_{1}, a_{2}, \ldots, a_{n}, a_{n+1}, \ldots\right\} \quad\left\{a_{n}\right\} \quad\left\{a_{n}\right\}_{n=1}^{\infty}
# $$
#
# Alternating but approaching 0 from both sides is same as approaching 0:
#
# $$\text { If } \lim_{n \rightarrow \infty}\left|a_{n}\right|=0 \text { then } \lim _{n \rightarrow \infty} a_{n}=0$$
#
#
# "Odd Even Theorem" (my own coinage) for Sequences.. For the sequence $\left\{a_{n}\right\}$ if both $\lim\limits_{n \rightarrow \infty} a_{2 n}=L$ and $\lim\limits_{n \rightarrow \infty} a_{2 n+1}=L$ then $\left\{a_{n}\right\}$ is convergent and $\lim_\limits{n \rightarrow \infty} a_{n}=L$. This is proven [at the bottom on Lamar here](https://tutorial.math.lamar.edu/Classes/CalcII/Sequences.aspx).
#
# ## Sequence Properties
#
# Given any sequence $\left\{a_{n}\right\}$ we have the following.
# 1. We call the sequence **increasing** if $a_{n}<a_{n+1}$ for every $n$.
# 2. We call the sequence **decreasing** if $a_{n}>a_{n+1}$ for every $n$.
# 3. If $\left\{a_{n}\right\}$ is an increasing sequence or $\left\{a_{n}\right\}$ is a decreasing sequence we call it **monotonic**.
# 4. If there exists a number $m$ such that $m \leq a_{n}$ for every $n$ we say the sequence is **bounded below**. The number $m$ is sometimes called a **lower bound** for the sequence.
# 5. If there exists a number $M$ such that $a_{n} \leq M$ for every $n$ we say the sequence is **bounded above**. The number $M$ is sometimes called an **upper bound** for the sequence.
# 6. If the sequence is both bounded below and bounded above we call the sequence **bounded**.
#
# Take the derivative to check for monotonicity. Look at critical points to identify possible sign changes.  If it's always positive or always negative, you're always increasing or decreasing, respectively.
#
# ## Sequence convergence
#
# If $\left\{a_{n}\right\}$ is bounded and monotonic then $\left\{a_{n}\right\}$ is convergent.
#
# The sequence $\left\{r^{n}\right\}_{n=0}^{\infty}$ converges if $-1<r \leq 1$ and diverges for all other values of $r$. Also,
# $$
# \lim _{n \rightarrow \infty} r^{n}= \begin{cases}0 & \text { if }-1<r<1 \\ 1 & \text { if } r=1\end{cases}
# $$
#
# ## Squeeze theorem for sequences
#
# $$\text { If } a_{n} \leq c_{n} \leq b_{n} \text { for all } n>N \text { for some } N \text { and } \lim _{n \rightarrow \infty} a_{n}=\lim _{n \rightarrow \infty} b_{n}=L \text { then } \lim _{n \rightarrow \infty} c_{n}=L \text {. }$$

# %% [markdown]
# # Series Basics / Infinite Series
#
# A **partial sum** $S_n$ is the sum of the first $n$ terms of a series.
#
# The nth term of a partial sum: $a_n = S_n - S_{n-1}$
#
# Infinite Series:
#
# $$
# \sum_{i=1}^{\infty} a_{i}=\lim _{n \rightarrow \infty} s_{n}
# $$
#
# # Convergence/Divergence of Series
#
# If the sequence of partial sums, $\left\{s_{n}\right\}_{n=1}^{\infty}$, is convergent and its limit is finite then we also call the infinite series, $\sum_{i=1}^{\infty} a_{i}$ **convergent** and if the sequence of partial sums is divergent then the infinite series is **divergent**.
#
# If $\sum a_{n}$ converges then $\lim _{n \rightarrow \infty} a_{n}=0$. Note on notation: when indexes aren't specified, assume it goes to infinity, and that it doesn't matter where it starts.
#
# [continya at proof.  expecting 2 more dayz on series]
#
# # Special Series
#
# ## Geometric Series
#
# ## Arithmetic Series
#
# ## Harmonic Series
#
# ## Telescoping Series
#
# Proof:
#
# ![image.png](attachment:d1aa18b9-0aba-4e73-a2bf-72841c1f8c4d.png)
#
# I wonder what's the general name for this technique of flipping the series around and adding it to itself?
#
# # Convergence Tests
#
# ## Integral Test
#
# ## Comparison Test / Limit Comparison Test
#
# ## Alternating Series Test
#
# ## Ratio Test
#
# ## Root Test
#
# # Absolute vs Conditional Convergence
#
# # Strategy for Series
#
# # Estimating the value of a Series (not sure if I need this as a section)
#
# # Power Series
#
# ## Power Series and Functions
#
# [Make sure we enumerate all dem power series, for same stuff we provided derivatives/integral of before]
#
# ## Taylor Series/Polynomials
#
# [cover dis]
#
# [make sure Maclurin gets highlighted]
#
# Note: Taylor Series is a special case of a Power Series.  But the [distinctions here are rather complex](https://math.stackexchange.com/questions/392918/are-taylor-series-and-power-series-the-same-thing) and worth revisiting later from an analysis perspective.
#
# ### Lagrange Error Bound
#
# We want to estimate $f(x)$ with a Taylor polynomial about $c$.
#
# $$f(x) = P_n(x) + R_n(x)$$
#
# Let
#
# $$ |f^{(n+1)}(z)| \le M \text{ where } z \in (c,x)$$
#
# Then the Lagrange bound for $R_{n}(x)$, the error of approximating $f(x)$ with the $n^{\text {th}}$ degree Taylor polynomial about $c$ is
#
# $$
# \left|R_{n}(x)\right| \leq\left|\frac{M}{(n+1) !}(x-c)^{n+1}\right|
# $$
#
# Combined as:
#
# $$
# \left|R_{n}(x)\right| \leq\left|\frac{f^{(n+1)}(z)}{(n+1) !}(x-c)^{n+1}\right| \text{ where } z \in (c,x)
# $$
#
# So you'll want to take the max in that interval, which so far for problems I've encountered is always on one of the endpoints.  So just check which endpoint (c or x) and use that one as the max.
#
# > Power series of the form Σk(x-a)ⁿ (where k is constant) are a geometric series with initial term k and common ratio (x-a).
#
# # Applications of Series (consider renaming or eliminating section)
#
# # Binomial Series
#
#
#
#
#
#
#
#
# [Math power series of e is best way to understand its magic]
